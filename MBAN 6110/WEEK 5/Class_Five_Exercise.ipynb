# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('/Users/yuchenzhang/Desktop/MBAN 6110/Lecture/module_5_feature_engineering_inclass.csv')

# %%
df.head()
# Out:
#    user_id  age       signup_date last_purchase_date  total_purchases
# 0        1   33  1978-11-01 17:03    2020-05-11 4:13               10  \
# 1        2   32  2016-04-08 14:19    1959-01-07 5:45                2
# 2        3   19   2021-03-08 7:01   2006-10-29 16:56                6
# 3        4   48  2006-01-11 11:04   1966-07-01 20:22                8
# 4        5   75   1985-06-16 1:41   2013-05-14 12:44                3
#
#    total_spent favorite_product_category           location  gender
# 0   840.954993                     books        Lake Gerald  female  \
# 1  1147.412095                     books  North Justinburgh    male
# 2  1301.284835                     books          West Alec  female
# 3  1404.261405                     books            Annaton    male
# 4  1968.752964                     books     East Markburgh  female
#
#   email_domain
# 0    gmail.com
# 1    yahoo.com
# 2    yahoo.com
# 3  hotmail.com
# 4    yahoo.com

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   user_id                    1000 non-null   int64
#  1   age                        1000 non-null   int64
#  2   signup_date                1000 non-null   object
#  3   last_purchase_date         1000 non-null   object
#  4   total_purchases            1000 non-null   int64
#  5   total_spent                1000 non-null   float64
#  6   favorite_product_category  1000 non-null   object
#  7   location                   1000 non-null   object
#  8   gender                     1000 non-null   object
#  9   email_domain               1000 non-null   object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 78.3+ KB

# %%
new_id = {'user_id':'ID'}
df.rename(columns=new_id, inplace=True)

# %%
df.head()
# Out:
#    ID  age       signup_date last_purchase_date  total_purchases  total_spent
# 0   1   33  1978-11-01 17:03    2020-05-11 4:13               10   840.954993  \
# 1   2   32  2016-04-08 14:19    1959-01-07 5:45                2  1147.412095
# 2   3   19   2021-03-08 7:01   2006-10-29 16:56                6  1301.284835
# 3   4   48  2006-01-11 11:04   1966-07-01 20:22                8  1404.261405
# 4   5   75   1985-06-16 1:41   2013-05-14 12:44                3  1968.752964
#
#   favorite_product_category           location  gender email_domain
# 0                     books        Lake Gerald  female    gmail.com
# 1                     books  North Justinburgh    male    yahoo.com
# 2                     books          West Alec  female    yahoo.com
# 3                     books            Annaton    male  hotmail.com
# 4                     books     East Markburgh  female    yahoo.com

# %%
# Transform datetime to a datetime data format
df['last_purchase_date'] = pd.to_datetime(df['last_purchase_date'])
df['signup_date'] = pd.to_datetime(df['signup_date'])

# %%
# Extract hour, month, day into new columns
df['p_hour'] = df['last_purchase_date'].dt.hour
df['p_day'] = df['last_purchase_date'].dt.day
df['p_month'] = df['last_purchase_date'].dt.month
df['p_year'] = df['last_purchase_date'].dt.year

# %%
df['s_hour'] = df['signup_date'].dt.hour
df['s_day'] = df['signup_date'].dt.day
df['s_month'] = df['signup_date'].dt.month
df['s_year'] = df['signup_date'].dt.year

# %%
df
# Out:
#        ID  age         signup_date  last_purchase_date  total_purchases
# 0       1   33 1978-11-01 17:03:00 2020-05-11 04:13:00               10  \
# 1       2   32 2016-04-08 14:19:00 1959-01-07 05:45:00                2
# 2       3   19 2021-03-08 07:01:00 2006-10-29 16:56:00                6
# 3       4   48 2006-01-11 11:04:00 1966-07-01 20:22:00                8
# 4       5   75 1985-06-16 01:41:00 2013-05-14 12:44:00                3
# ..    ...  ...                 ...                 ...              ...
# 995   996   69 1994-01-02 01:26:00 2002-12-06 01:07:00               48
# 996   997   35 1957-10-19 19:41:00 1977-07-19 00:45:00               45
# 997   998   49 1970-01-23 00:10:00 1986-11-01 04:45:00               38
# 998   999   61 2016-02-26 21:04:00 1952-01-11 10:28:00               12
# 999  1000   50 1982-02-02 07:25:00 2010-04-24 10:07:00               30
#
#      total_spent favorite_product_category               location  gender
# 0     840.954993                     books            Lake Gerald  female  \
# 1    1147.412095                     books      North Justinburgh    male
# 2    1301.284835                     books              West Alec  female
# 3    1404.261405                     books                Annaton    male
# 4    1968.752964                     books         East Markburgh  female
# ..           ...                       ...                    ...     ...
# 995  1395.669474                      home         Cynthiaborough  female
# 996   131.001416               electronics  North Christopherside  female
# 997   102.663709               electronics             Castroland    male
# 998  1022.037997                  clothing             Salasmouth  female
# 999   333.873768                  clothing              Smithstad  female
#
#     email_domain  p_hour  p_day  p_month  p_year  s_hour  s_day  s_month
# 0      gmail.com       4     11        5    2020      17      1       11  \
# 1      yahoo.com       5      7        1    1959      14      8        4
# 2      yahoo.com      16     29       10    2006       7      8        3
# 3    hotmail.com      20      1        7    1966      11     11        1
# 4      yahoo.com      12     14        5    2013       1     16        6
# ..           ...     ...    ...      ...     ...     ...    ...      ...
# 995    gmail.com       1      6       12    2002       1      2        1
# 996    gmail.com       0     19        7    1977      19     19       10
# 997  hotmail.com       4      1       11    1986       0     23        1
# 998  hotmail.com      10     11        1    1952      21     26        2
# 999    yahoo.com      10     24        4    2010       7      2        2
#
#      s_year
# 0      1978
# 1      2016
# 2      2021
# 3      2006
# 4      1985
# ..      ...
# 995    1994
# 996    1957
# 997    1970
# 998    2016
# 999    1982
#
# [1000 rows x 18 columns]

# %%
df = df[df['p_year'] >= df['s_year']]

# %%
df
# Out:
#        ID  age         signup_date  last_purchase_date  total_purchases
# 0       1   33 1978-11-01 17:03:00 2020-05-11 04:13:00               10  \
# 4       5   75 1985-06-16 01:41:00 2013-05-14 12:44:00                3
# 5       6   76 1960-02-12 12:06:00 1996-10-02 14:24:00               46
# 7       8   57 1979-12-24 05:37:00 2008-09-10 15:42:00               18
# 8       9   52 1980-12-22 23:02:00 1986-02-03 05:05:00               49
# ..    ...  ...                 ...                 ...              ...
# 994   995   28 1993-10-25 13:32:00 2002-09-02 13:52:00                1
# 995   996   69 1994-01-02 01:26:00 2002-12-06 01:07:00               48
# 996   997   35 1957-10-19 19:41:00 1977-07-19 00:45:00               45
# 997   998   49 1970-01-23 00:10:00 1986-11-01 04:45:00               38
# 999  1000   50 1982-02-02 07:25:00 2010-04-24 10:07:00               30
#
#      total_spent favorite_product_category               location  gender
# 0     840.954993                     books            Lake Gerald  female  \
# 4    1968.752964                     books         East Markburgh  female
# 5    1901.805183                      home           Port Melanie  female
# 7    1739.610644               electronics            Antonioview  female
# 8    1069.404308                  clothing           Cynthiaville    male
# ..           ...                       ...                    ...     ...
# 994   912.918996                    beauty            Crystalside  female
# 995  1395.669474                      home         Cynthiaborough  female
# 996   131.001416               electronics  North Christopherside  female
# 997   102.663709               electronics             Castroland    male
# 999   333.873768                  clothing              Smithstad  female
#
#     email_domain  p_hour  p_day  p_month  p_year  s_hour  s_day  s_month
# 0      gmail.com       4     11        5    2020      17      1       11  \
# 4      yahoo.com      12     14        5    2013       1     16        6
# 5      yahoo.com      14      2       10    1996      12     12        2
# 7      yahoo.com      15     10        9    2008       5     24       12
# 8      gmail.com       5      3        2    1986      23     22       12
# ..           ...     ...    ...      ...     ...     ...    ...      ...
# 994  hotmail.com      13      2        9    2002      13     25       10
# 995    gmail.com       1      6       12    2002       1      2        1
# 996    gmail.com       0     19        7    1977      19     19       10
# 997  hotmail.com       4      1       11    1986       0     23        1
# 999    yahoo.com      10     24        4    2010       7      2        2
#
#      s_year
# 0      1978
# 4      1985
# 5      1960
# 7      1979
# 8      1980
# ..      ...
# 994    1993
# 995    1994
# 996    1957
# 997    1970
# 999    1982
#
# [495 rows x 18 columns]

# %%
MAX_p_year = df['p_year'].max()

# %%
MAX_p_year
# Out:
# 2023

# %%
# cacluate the total year of sign up
df['ts_year'] = 2023 - df['s_year']
# Out:
# /var/folders/1s/1ydr33r9161b79pnkp2c_0fm0000gn/T/ipykernel_40176/1603630754.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ts_year'] = 2023 - df['s_year']

# %%
df
# Out:
#        ID  age         signup_date  last_purchase_date  total_purchases
# 0       1   33 1978-11-01 17:03:00 2020-05-11 04:13:00               10  \
# 4       5   75 1985-06-16 01:41:00 2013-05-14 12:44:00                3
# 5       6   76 1960-02-12 12:06:00 1996-10-02 14:24:00               46
# 7       8   57 1979-12-24 05:37:00 2008-09-10 15:42:00               18
# 8       9   52 1980-12-22 23:02:00 1986-02-03 05:05:00               49
# ..    ...  ...                 ...                 ...              ...
# 994   995   28 1993-10-25 13:32:00 2002-09-02 13:52:00                1
# 995   996   69 1994-01-02 01:26:00 2002-12-06 01:07:00               48
# 996   997   35 1957-10-19 19:41:00 1977-07-19 00:45:00               45
# 997   998   49 1970-01-23 00:10:00 1986-11-01 04:45:00               38
# 999  1000   50 1982-02-02 07:25:00 2010-04-24 10:07:00               30
#
#      total_spent favorite_product_category               location  gender
# 0     840.954993                     books            Lake Gerald  female  \
# 4    1968.752964                     books         East Markburgh  female
# 5    1901.805183                      home           Port Melanie  female
# 7    1739.610644               electronics            Antonioview  female
# 8    1069.404308                  clothing           Cynthiaville    male
# ..           ...                       ...                    ...     ...
# 994   912.918996                    beauty            Crystalside  female
# 995  1395.669474                      home         Cynthiaborough  female
# 996   131.001416               electronics  North Christopherside  female
# 997   102.663709               electronics             Castroland    male
# 999   333.873768                  clothing              Smithstad  female
#
#     email_domain  p_hour  p_day  p_month  p_year  s_hour  s_day  s_month
# 0      gmail.com       4     11        5    2020      17      1       11  \
# 4      yahoo.com      12     14        5    2013       1     16        6
# 5      yahoo.com      14      2       10    1996      12     12        2
# 7      yahoo.com      15     10        9    2008       5     24       12
# 8      gmail.com       5      3        2    1986      23     22       12
# ..           ...     ...    ...      ...     ...     ...    ...      ...
# 994  hotmail.com      13      2        9    2002      13     25       10
# 995    gmail.com       1      6       12    2002       1      2        1
# 996    gmail.com       0     19        7    1977      19     19       10
# 997  hotmail.com       4      1       11    1986       0     23        1
# 999    yahoo.com      10     24        4    2010       7      2        2
#
#      s_year  ts_year
# 0      1978       45
# 4      1985       38
# 5      1960       63
# 7      1979       44
# 8      1980       43
# ..      ...      ...
# 994    1993       30
# 995    1994       29
# 996    1957       66
# 997    1970       53
# 999    1982       41
#
# [495 rows x 19 columns]

# %%
df = df[df['ts_year'] <= df['age']]

# %%
df
# Out:
#        ID  age         signup_date  last_purchase_date  total_purchases
# 4       5   75 1985-06-16 01:41:00 2013-05-14 12:44:00                3  \
# 5       6   76 1960-02-12 12:06:00 1996-10-02 14:24:00               46
# 7       8   57 1979-12-24 05:37:00 2008-09-10 15:42:00               18
# 8       9   52 1980-12-22 23:02:00 1986-02-03 05:05:00               49
# 22     23   57 1968-03-04 23:23:00 2020-08-16 07:27:00               21
# ..    ...  ...                 ...                 ...              ...
# 960   961   34 1995-03-08 17:29:00 1996-02-21 23:13:00               30
# 982   983   73 2004-03-08 18:17:00 2009-05-20 11:05:00                5
# 986   987   63 1977-07-07 22:19:00 1982-12-31 09:14:00               38
# 995   996   69 1994-01-02 01:26:00 2002-12-06 01:07:00               48
# 999  1000   50 1982-02-02 07:25:00 2010-04-24 10:07:00               30
#
#      total_spent favorite_product_category        location  gender
# 4    1968.752964                     books  East Markburgh  female  \
# 5    1901.805183                      home    Port Melanie  female
# 7    1739.610644               electronics     Antonioview  female
# 8    1069.404308                  clothing    Cynthiaville    male
# 22    485.797815                     books   West Jonathon  female
# ..           ...                       ...             ...     ...
# 960  1723.399979                      home    East Shannon  female
# 982  1176.104173                    beauty     New Allison  female
# 986  1250.413768                    beauty      Lestertown  female
# 995  1395.669474                      home  Cynthiaborough  female
# 999   333.873768                  clothing       Smithstad  female
#
#     email_domain  p_hour  p_day  p_month  p_year  s_hour  s_day  s_month
# 4      yahoo.com      12     14        5    2013       1     16        6  \
# 5      yahoo.com      14      2       10    1996      12     12        2
# 7      yahoo.com      15     10        9    2008       5     24       12
# 8      gmail.com       5      3        2    1986      23     22       12
# 22     gmail.com       7     16        8    2020      23      4        3
# ..           ...     ...    ...      ...     ...     ...    ...      ...
# 960    gmail.com      23     21        2    1996      17      8        3
# 982    gmail.com      11     20        5    2009      18      8        3
# 986    gmail.com       9     31       12    1982      22      7        7
# 995    gmail.com       1      6       12    2002       1      2        1
# 999    yahoo.com      10     24        4    2010       7      2        2
#
#      s_year  ts_year
# 4      1985       38
# 5      1960       63
# 7      1979       44
# 8      1980       43
# 22     1968       55
# ..      ...      ...
# 960    1995       28
# 982    2004       19
# 986    1977       46
# 995    1994       29
# 999    1982       41
#
# [265 rows x 19 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 265 entries, 4 to 999
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   ID                         265 non-null    int64
#  1   age                        265 non-null    int64
#  2   signup_date                265 non-null    datetime64[ns]
#  3   last_purchase_date         265 non-null    datetime64[ns]
#  4   total_purchases            265 non-null    int64
#  5   total_spent                265 non-null    float64
#  6   favorite_product_category  265 non-null    object
#  7   location                   265 non-null    object
#  8   gender                     265 non-null    object
#  9   email_domain               265 non-null    object
#  10  p_hour                     265 non-null    int32
#  11  p_day                      265 non-null    int32
#  12  p_month                    265 non-null    int32
#  13  p_year                     265 non-null    int32
#  14  s_hour                     265 non-null    int32
#  15  s_day                      265 non-null    int32
#  16  s_month                    265 non-null    int32
#  17  s_year                     265 non-null    int32
#  18  ts_year                    265 non-null    int32
# dtypes: datetime64[ns](2), float64(1), int32(9), int64(3), object(4)
# memory usage: 32.1+ KB

# %%
df['lp'] = df['p_year'] - df['s_year']
# Out:
# /var/folders/1s/1ydr33r9161b79pnkp2c_0fm0000gn/T/ipykernel_40176/3594645158.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['lp'] = df['p_year'] - df['s_year']

# %%
df_mean = pd.DataFrame(df[['age', 'total_spent', 'total_purchases', 'ts_year']].mean())

# %%
df_mean
# Out:
#                            0
# age                61.686792
# total_spent      1013.563537
# total_purchases    23.864151
# ts_year            41.256604
