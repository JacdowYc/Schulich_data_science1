# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/Users/yuchenzhang/Desktop/messy_data.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 df = pd.read_csv('/Users/yuchenzhang/Desktop/messy_data.csv')
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       105 non-null    int64
#  1   Income    94 non-null     float64
#  2   Gender    105 non-null    object
#  3   Product   100 non-null    object
#  4   Quantity  105 non-null    int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.2+ KB

# %%
df.describe(include="all")
# Out:
#                Age         Income  Gender Product   Quantity
# count   105.000000      94.000000     105     100  105.00000
# unique         NaN            NaN       2       4        NaN
# top            NaN            NaN  Female       D        NaN
# freq           NaN            NaN      58      28        NaN
# mean     42.076190   52867.862808     NaN     NaN    3.20000
# std      15.940813   29896.579420     NaN     NaN    1.44382
# min      18.000000   20901.331720     NaN     NaN    1.00000
# 25%      31.000000   37814.315255     NaN     NaN    2.00000
# 50%      41.000000   48760.369705     NaN     NaN    3.00000
# 75%      55.000000   61644.277868     NaN     NaN    5.00000
# max     120.000000  300000.000000     NaN     NaN    5.00000

# %%
data = [45, 55, 60, 50, 80, 62, 54, 58, 71, 48]

# %%
mean = np.mean(data)
median = np.median(data)
print("mean: ", mean)
print("median", median)
# Out:
# mean:  58.3
# median 56.5

# %%
range = np.ptp(data)
variance = np.var(data)
SD = np.std(data)
print(range)
print(variance)
print(SD)
# Out:
# 35
# 103.01000000000002
# 10.149384217774003

# %%
df = pd.read_csv("/Users/yuchenzhang/Desktop/MBAN 6110/messy_data.csv")

# %%
df
# Out:
#      Age       Income  Gender Product  Quantity
# 0     56  59544.57663  Female       D         3
# 1     46  36399.18997  Female     NaN         1
# 2     32  57140.63881  Female       D         2
# 3     60  69554.91903    Male       C         5
# 4     25  53173.80518  Female       D         2
# ..   ...          ...     ...     ...       ...
# 100   61  37341.55459    Male       D         5
# 101   55  35516.63492  Female       A         3
# 102   31  53254.05089    Male       B         2
# 103   21          NaN    Male       B         2
# 104   60  69554.91903    Male       C         5
#
# [105 rows x 5 columns]

# %%
# Write a Function to find the average income by Gender
df_gender = df.groupby("Gender")
df_gender.groups
# Out:
# {'Female': [0, 1, 2, 4, 5, 7, 9, 10, 11, 14, 21, 22, 24, 25, 26, 27, 29, 30, 33, 34, 35, 36, 37, 38, 40, 41, 46, 47, 48, 49, 50, 51, 53, 56, 58, 60, 62, 63, 64, 65, 66, 70, 72, 73, 76, 78, 79, 80, 81, 82, 85, 86, 89, 91, 93, 95, 98, 101], 'Male': [3, 6, 8, 12, 13, 15, 16, 17, 18, 19, 20, 23, 28, 31, 32, 39, 42, 43, 44, 45, 52, 54, 55, 57, 59, 61, 67, 68, 69, 71, 74, 75, 77, 83, 84, 87, 88, 90, 92, 94, 96, 97, 99, 100, 102, 103, 104]}

# %%
df_gender['Income'].mean()
# Out:
# Gender
# Female    49644.486259
# Male      57219.421148
# Name: Income, dtype: float64

# %%
df_product = df.groupby('Product')
df_product['Income'].mean()
# Out:
# Product
# A    51745.423588
# B    61486.730790
# C    50857.602438
# D    49876.379810
# Name: Income, dtype: float64

# %%
df_customer = df.groupby('Product')
df_customer["Age"].count()
df_customer["Gender"].count()
# Out:
# Product
# A    23
# B    25
# C    24
# D    28
# Name: Gender, dtype: int64

# %%
df['Income'].describe()
# Out:
# count        94.000000
# mean      52867.862808
# std       29896.579420
# min       20901.331720
# 25%       37814.315255
# 50%       48760.369705
# 75%       61644.277868
# max      300000.000000
# Name: Income, dtype: float64

# %%
df.groupby('Gender')['Income'].describe()
# Out:
#         count          mean           std          min           25%
# Gender
# Female   54.0  49644.486259  15220.366090  27763.63630  37549.629215  \
# Male     40.0  57219.421148  42222.682325  20901.33172  38144.018710
#
#                  50%           75%           max
# Gender
# Female  47443.734975  59180.209903   94154.95125
# Male    52807.321410  63330.314347  300000.00000

# %%
sns.histplot(df['Income'])
# Out:
# <Axes: xlabel='Income', ylabel='Count'>

# %%
df.describe()
# Out:
#               Age         Income   Quantity
# count  105.000000      94.000000  105.00000
# mean    42.076190   52867.862808    3.20000
# std     15.940813   29896.579420    1.44382
# min     18.000000   20901.331720    1.00000
# 25%     31.000000   37814.315255    2.00000
# 50%     41.000000   48760.369705    3.00000
# 75%     55.000000   61644.277868    5.00000
# max    120.000000  300000.000000    5.00000

# %%
df[df['Income'] > 250000]
# Out:
#     Age    Income Gender Product  Quantity
# 99   61  300000.0   Male       B         4

# %%
df_no = df["Income"].drop(99)

# %%
df_no
# Out:
#      Age       Income  Gender Product  Quantity
# 0     56  59544.57663  Female       D         3
# 1     46  36399.18997  Female     NaN         1
# 2     32  57140.63881  Female       D         2
# 3     60  69554.91903    Male       C         5
# 4     25  53173.80518  Female       D         2
# ..   ...          ...     ...     ...       ...
# 100   61  37341.55459    Male       D         5
# 101   55  35516.63492  Female       A         3
# 102   31  53254.05089    Male       B         2
# 103   21          NaN    Male       B         2
# 104   60  69554.91903    Male       C         5
#
# [104 rows x 5 columns]

# %%
relplot

# %%
sns.histplot(df_no['Income'])
# Out:
# <Axes: xlabel='Income', ylabel='Count'>

# %%
df_noout = df.set_index('Income').drop(300000)

# %%
sns.histplot(df_noout.reset_index()['Income'])
# Out:
# <Axes: xlabel='Income', ylabel='Count'>

# %%
sns.boxplot(df_no['Income'])
# Out:
# <Axes: >

# %%
sns.catplot(data = df_no, x='Gender', y='Income', kind='box')

# %%
sns.catplot(data = df_no, x='Gender', y='Income', kind='bar')

# %%
sns.catplot(data = df_no, x='Product', y='Income', kind='box', ci=None)

# %%
sns.catplot(data = df_no, x='Product', y='Income', kind='box', ci=None, sym="")

# %%
df_no.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 104 entries, 0 to 104
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       104 non-null    int64
#  1   Income    93 non-null     float64
#  2   Gender    104 non-null    object
#  3   Product   99 non-null     object
#  4   Quantity  104 non-null    int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 8.9+ KB

# %%
df_no.groupby('Gender')['Income'].median()
# Out:
# Gender
# Female    47443.734975
# Male      52529.890810
# Name: Income, dtype: float64

# %%
male_clean = df_no[df_no['Gender']=='Male'].fillna(52529.890810)

# %%
female_clean = df_no[df_no['Gender']=='Female'].fillna( 47443.734975)

# %%
male_clean
# Out:
#      Age       Income Gender      Product  Quantity
# 3     60  69554.91903   Male            C         5
# 6     56  36554.97225   Male            D         1
# 8     40  72034.11928   Male            D         2
# 12    53  52529.89081   Male            B         1
# 13    57  24735.68932   Male            A         5
# 15    20  48783.21569   Male            C         4
# 16    39  57016.92130   Male            D         4
# 17    19  61041.83526   Male            A         5
# 18    41  38304.47179   Male            A         4
# 19    61  37341.55459   Male            D         5
# 20    47  47741.99213   Male            A         4
# 23    38  48298.68123   Male            A         5
# 28    42  52529.89081   Male            D         1
# 31    45  62355.99615   Male            A         2
# 32    33  52529.89081   Male            D         2
# 39    38  52529.89081   Male            A         1
# 42    35  52529.89081   Male            B         1
# ...

# %%
female_clean
# Out:
#      Age        Income  Gender       Product  Quantity
# 0     56  59544.576630  Female             D         3
# 1     46  36399.189970  Female  47443.734975         1
# 2     32  57140.638810  Female             D         2
# 4     25  53173.805180  Female             D         2
# 5     38  58955.669690  Female             A         2
# 7     36  48320.182690  Female             A         4
# 9     28  33141.524980  Female             D         3
# 10    28  64250.080930  Female             B         4
# 11    41  47443.734975  Female             A         5
# 14    41  54902.678360  Female             B         4
# 21    55  35516.634920  Female             A         3
# 22    19  52257.336170  Female             B         4
# 24    50  89502.923310  Female             C         2
# 25    29  34623.636670  Female             C         4
# 26    39  38269.282610  Female             D         2
# 27    61  56359.146050  Female             A         3
# ...

# %%
df_clean =pd.concat([male_clean, female_clean], axis=0)

# %%
df_no['Income'] = df_no['Income'].fillna(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/1s/1ydr33r9161b79pnkp2c_0fm0000gn/T/ipykernel_84349/2893536733.py in ?()
# ----> 1 df_no['Income'] = df_no['Income'].fillna(df)
#
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/series.py in ?(self, value, method, axis, inplace, limit, downcast)
#    5137         inplace: bool = False,
#    5138         limit: int | None = None,
#    5139         downcast: dict | None = None,
#    5140     ) -> Series | None:
# -> 5141         return super().fillna(
#    5142             value=value,
#    5143             method=method,
#    5144             axis=axis,
#
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, value, method, axis, inplace, limit, downcast)
#    6894                     value = value._values
# ...
